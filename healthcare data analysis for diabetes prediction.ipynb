# %% [markdown]
# i able of contents:1)goals
#     2)data:loding the data and data information 3)exploratary data analysis:a.examination of diabetic and non-diavetic people above 50year d.number of diabetic pople above50yr a

# %% [markdown]
# # scoping

# %% [markdown]
# this project contain 4 section
# 1)the 1 st section is the project goal3 this section will defime high level objective and set intention for this project.
# 2) the 2 nd section is the dataset downloaded from kaggle.
# 3) the 3 rd section is of analysis of data to get  insights from it and simultaneously conclus is mentioned.

# %% [markdown]
# # goal

# %% [markdown]
# this notebook contains an analysis on some diabetesprediction dataset.the goal for thid project was to do the following
# 1)get acquained with the data
# 2)visualice the distribution of featires and there relationships with the diabetes outcome.
# 3)analyze potential patterns or trends in the data

# %%
# %matplotlib notebook
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.shape
# Out:
# (768, 9)

# %% [markdown]
# # 1) to examine people with and wirhout diabetes.

# %%
df["Outcome"].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %% [markdown]
# cunclusion = 500 people donts have diavetes and 268 people hasdiabetes.

# %%
plt.figure(figsize=(4,4))
sns.countplot(x=df['Outcome'])
plt.legend(title='Outcome')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(4,4))
category_counts = df["Outcome"].value_counts()
category_counts.plot(kind='pie',autopct="%1.2f%%")
plt.title("distribution of people with and without diabetes.")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %% [markdown]
# # 3)number of non diabetic people above 50 years

# %%
y=df[(df['Age']>50) & (df['Outcome']==0)]
y.shape
# Out:
# (43, 9)

# %% [markdown]
# # 4)number of diabetic people above 50 yr.

# %%
v=df[(df['Age']>50) & (df['Outcome']==1)]
v.shape
# Out:
# (38, 9)

# %% [markdown]
# # 2)examination of diabetic and non_deavetic people with other issues.

# %%
var_cols = ['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI']
plot = 0
fig=plt.figure(figsize=(8,8))
for i in range(len(var_cols)):
    plot+=1
    ax=plt.subplot(3,2,plot)
    sns.boxplot(x=df["Outcome"],y=df[var_cols[i]],palette="viridis")
    plt.title("diavetic and non diavetic people with oher issues")
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
plt.figure(figsize=(7,7))
sns.heatmap(df.corr())
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">
